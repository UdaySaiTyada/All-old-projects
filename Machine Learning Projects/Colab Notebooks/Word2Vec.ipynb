# %%
import nltk
nltk.download('punkt')
nltk.download('abc')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package abc to /root/nltk_data...
# [nltk_data]   Unzipping corpora/abc.zip.
# True

# %%
import gensim
# from nltk.corpus import abc
from nltk.corpus import punkt



model= gensim.models.Word2Vec(punkt.sents())
x= list(model.wv.vocab)
# data=model.most_similar('I love working')
# print(data)
print(x)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-5d7c41f56134> in <module>()
#       1 import gensim
#       2 # from nltk.corpus import abc
# ----> 3 from nltk.corpus import punkt
#       4
#       5
#
# ImportError: cannot import name 'punkt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
sentence1 = "I am going to India".lower().split()
sentence2 = "I am going to bharat".lower().split()
print(sentence1, sentence2)
# Out:
# ['i', 'am', 'going', 'to', 'india'] ['i', 'am', 'going', 'to', 'bharat']

# %%
from nltk.corpus import stopwords
stopwords = nltk.corpus.stopwords.words('english')

# %%
sentence1 = [w for w in sentence1 if w not in stopwords]
sentence2 = [w for w in sentence2 if w not in stopwords]
print(sentence1, sentence2)
# Out:
# ['going', 'india'] ['going', 'bharat']

# %%
distance = model.wmdistance(sentence1, sentence2)
print(distance)
# Out:
# 0.0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `wmdistance` (Method will be removed in 4.0.0, use self.wv.wmdistance() instead).
